# %%
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# create a session to run the tensors
sess = tf.Session()

# %%
# Defining Values
values = np.linspace(-10, 10, 30)
errors = (np.random.random(values.shape) * 2 - 1) * 30
result = 5 * values + errors

plt.grid(True)
plt.xlabel('X')
plt.ylabel('Y')

plt.scatter(values, result)

plt.show()

# %%
# Defining Tensors
xt = tf.constant(values, tf.float32)
yt = tf.constant(result, tf.float32)
wt = tf.placeholder(tf.float32)

# %%
# Linear Regression
plt.grid(True)
plt.xlabel('X')
plt.ylabel('Y')
plt.scatter(values, result)
    
for w in range(10):
    yt_pred = xt * wt
    x, y = sess.run((xt, yt_pred), {wt:w})
    plt.plot(x, y, color='red')

plt.show()

# %%
# Best Linear Regression
def plot_best():
    min_err = np.array(err).min()
    min_idx = err.index(min_err)
    min_w = steps[min_idx]

    plt.title(f'y = {min_w} * x')

    plt.grid(True)
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.scatter(values, result)

    x, y = sess.run((xt, yt_pred), {wt:min_w})
    plt.plot(x, y, color='red')

    plt.show()

# %%
# Mean Absolute Error
def mae(yt, yt_pred):
    return tf.reduce_sum(tf.abs(yt - yt_pred)) / tf.cast(tf.size(yt), tf.float32)

err = []
steps = np.linspace(0, 10, 100)
for w in steps:
    yt_pred = xt * wt
    # error = tf.keras.losses.MAE(yt, yt_pred)
    error = mae(yt, yt_pred)
    err.append(sess.run(error, {wt:w}))

print(err)

plot_best()
# Out:
# [26.892225, 26.49283, 26.103472, 25.715687, 25.327902, 24.940115, 24.552328, 24.164543, 23.776756, 23.388971, 23.001184, 22.6134, 22.225613, 21.837826, 21.450045, 21.062258, 20.674473, 20.286684, 19.8989, 19.511114, 19.123327, 18.735542, 18.372774, 18.052326, 17.80398, 17.598248, 17.428732, 17.259224, 17.08971, 16.9202, 16.75069, 16.581179, 16.437967, 16.328941, 16.252312, 16.175684, 16.099056, 16.022429, 15.960461, 15.909376, 15.85829, 15.807203, 15.756119, 15.705032, 15.653948, 15.642194, 15.630584, 15.618973, 15.607363, 15.6330385, 15.674835, 15.716632, 15.75843, 15.805836, 15.905685, 16.005533, 16.105383, 16.20523, 16.30508, 16.456781, 16.62397, 16.79116, 16.958347, 17.125538, 17.292725, 17.459917, 17.631798, 17.83846, 18.045126, 18.251791, 18.458456, 18.665121, 18.875309, 19.169333, 19.478737, 19.845621, 20.21251, 20.579395, 20.946283, 21.313171, 21.692482, 22.089558, 22.486633, 22.883709, 23.280779, 23.711033, 24.152225, 24.593418, 25.034613, 25.475805, 25.916998, 26.358192, 26.808529, 27.293835, 27.779152, 28.264465, 28.749777, 29.235088, 29.720402, 30.205715]

# %%
# Mean Square Error
def mse(yt, yt_pred):
    return tf.reduce_sum((yt - yt_pred) ** 2) / tf.cast(tf.size(yt), tf.float32)

err = []
steps = np.linspace(0, 10, 100)
for w in steps:
    yt_pred = xt * wt
    # error = tf.keras.losses.MSE(yt, yt_pred)
    error = mse(yt, yt_pred)
    err.append(sess.run(error, {wt:w}))

print(err)

plot_best()
# Out:
# [1109.1394, 1075.2416, 1042.0707, 1009.6269, 977.9103, 946.9207, 916.6584, 887.12305, 858.3149, 830.23376, 802.8799, 776.2531, 750.35333, 725.1808, 700.73517, 677.01685, 654.02563, 631.7615, 610.22437, 589.4145, 569.33167, 549.97595, 531.34735, 513.4459, 496.2715, 479.82428, 464.10416, 449.11115, 434.8452, 421.3064, 408.49475, 396.41025, 385.05276, 374.42242, 364.51917, 355.34305, 346.89404, 339.17215, 332.1774, 325.90973, 320.36917, 315.55576, 311.46942, 308.11023, 305.47815, 303.57312, 302.39526, 301.94452, 302.2209, 303.22433, 304.95493, 307.41263, 310.59744, 314.50937, 319.14838, 324.51453, 330.60782, 337.42822, 344.97568, 353.2503, 362.252, 371.98087, 382.43677, 393.61984, 405.53, 418.16733, 431.53168, 445.6232, 460.44183, 475.98755, 492.26038, 509.26038, 526.9875, 545.44165, 564.6229, 584.5314, 605.16693, 626.5295, 648.6193, 671.43616, 694.98004, 719.2512, 744.24945, 769.97485, 796.42706, 823.60675, 851.51337, 880.14734, 909.50824, 939.596, 970.41113, 1001.9534, 1034.2229, 1067.2192, 1100.9427, 1135.3936, 1170.5714, 1206.4761, 1243.108, 1280.4674]

# %%
# R²
def r_squared(yt, yt_pred):
    residual = tf.reduce_sum((yt - yt_pred) ** 2)
    total = tf.reduce_sum((yt - tf.reduce_mean(yt)) ** 2)
    return residual / total

err = []
steps = np.linspace(0, 10, 100)
for w in steps:
    yt_pred = xt * wt
    error = r_squared(yt, yt_pred)
    err.append(sess.run(error, {wt:w}))

print(err)

plot_best()
# Out:
# [1.0025184, 0.9718791, 0.9418969, 0.91257197, 0.8839043, 0.8558937, 0.82854044, 0.80184436, 0.77580553, 0.7504238, 0.7256994, 0.70163226, 0.67822224, 0.6554695, 0.63337386, 0.61193556, 0.59115446, 0.57103056, 0.5515638, 0.53275436, 0.5146021, 0.49710703, 0.4802692, 0.4640886, 0.44856519, 0.433699, 0.41949007, 0.40593833, 0.39304376, 0.38080642, 0.36922637, 0.35830352, 0.34803784, 0.3384294, 0.3294781, 0.3211841, 0.31354728, 0.3065677, 0.30024534, 0.2945802, 0.28957224, 0.28522152, 0.28152803, 0.27849177, 0.27611268, 0.2743908, 0.27332616, 0.27291873, 0.27316853, 0.27407554, 0.27563977, 0.2778612, 0.28073987, 0.28427574, 0.2884688, 0.2933191, 0.29882666, 0.3049914, 0.31181332, 0.31929255, 0.3274289, 0.33622253, 0.34567332, 0.35578138, 0.3665466, 0.37796912, 0.39004874, 0.40278566, 0.41617978, 0.43023112, 0.44493964, 0.46030542, 0.47632846, 0.4930086, 0.51034606, 0.52834064, 0.54699254, 0.5663015, 0.5862678, 0.60689133, 0.628172, 0.65010995, 0.6727051, 0.69595754, 0.71986693, 0.7444338, 0.76965785, 0.7955392, 0.8220777, 0.84927315, 0.877126, 0.90563613, 0.93480355, 0.964628, 0.9951097, 1.0262487, 1.058045, 1.0904982, 1.1236087, 1.1573766]

# %%
# closing session
sess.close()
